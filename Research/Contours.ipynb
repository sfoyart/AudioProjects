# %%
import cv2, numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("../../../../Pictures/P_20161105_155540.jpg")
edges = cv2.Canny(img,100,200)
plt.figure(figsize=(16,18))
plt.subplot(211),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(212),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# (<matplotlib.text.Text at 0x7f2513dec240>,
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
img
# Out:
# array([[[  7,  14,  17],
#         [  7,  14,  17],
#         [  7,  14,  17],
#         ...,
#         [  4,  83,  74],
#         [  3,  72,  59],
#         [ 22,  76,  63]],
#
#        [[  8,  15,  18],
#         [  8,  15,  18],
#         [  7,  14,  17],
#         ...,
#         [ 20,  95,  93],
#         [ 27,  93,  88],
#         [ 36,  92,  87]],
#
#        [[  9,  16,  19],
#         [  8,  15,  18],
#         [  8,  15,  18],
#         ...,
#         [ 30,  95, 104],
#         [ 29,  92, 100],
#         [ 37,  97, 103]],
#
#        ...,
#        [[ 49,  46,  41],
#         [ 53,  50,  45],
#         [ 55,  52,  47],
#         ...,
#         [105, 152, 173],
#         [114, 158, 171],
#         [123, 162, 170]],
#
#        [[ 52,  49,  44],
#         [ 50,  47,  42],
#         [ 50,  47,  42],
#         ...,
#         [114, 162, 180],
#         [113, 158, 169],
#         [117, 157, 162]],
#
#        [[ 63,  60,  55],
#         [ 56,  53,  48],
#         [ 51,  48,  43],
#         ...,
#         [105, 153, 171],
#         [110, 155, 166],
#         [112, 152, 157]]], dtype=uint8)
